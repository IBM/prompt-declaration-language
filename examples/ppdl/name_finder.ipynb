# %%
from mu_ppl import *
from pdl.pdl import exec_file

# %%
def name_finder():
    p = exec_file("name_finder.pdl")
    return p

# %%
with ImportanceSampling(num_particles=10):
    dist1: Empirical[str] = infer(name_finder)  # type: ignore
# Out:
# 100%|██████████| 10/10 [00:29<00:00,  2.99s/it]

# %%
viz(dist1)
# Out:
# /Users/lmandel/probabilistic/mu-ppl/mu_ppl/distributions.py:89: RuntimeWarning: divide by zero encountered in log
#   self.logits = np.log(self.probs)

# %%
with RejectionSampling(num_samples=10):
    dist2: Empirical[str] = infer(name_finder)  # type: ignore
# Out:
#  10%|█         | 1/10 [03:25<30:52, 205.83s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:285, in process_block(state, scope, block, loc)
#     284     else:
# --> 285         result, background, scope, trace = process_advanced_block_timed(
#     286             state, scope, block, loc
#     287         )
#     288 except EOFError as exc:
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:326, in process_advanced_block_timed(state, scope, block, loc)
#     325 block.pdl__timing.start_nanos = time.time_ns()
# --> 326 result, background, scope, trace = process_advanced_block(state, scope, block, loc)
#     327 block.pdl__timing.end_nanos = time.time_ns()
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:368, in process_advanced_block(state, scope, block, loc)
#     367 try:
# --> 368     result, background, new_scope, trace = process_block_body(
#     369         state, scope, block, loc
#     370     )
#     371     result = lazy_apply(id_with_set_first_use_nanos(block.pdl__timing), result)
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:471, in process_block_body(state, scope, block, loc)
#     470 case ArgsBlock() | CodeBlock():
# --> 471     result, background, scope, trace = process_call_code(
#     472         state, scope, block, loc
#     473     )
#     474     if state.yield_result:
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:1568, in process_call_code(state, scope, block, loc)
#    1567 try:
# -> 1568     result = call_python(code_s, scope)
#    1569     background = PdlList(
#    1570         [PdlDict({"role": state.role, "content": lazy_apply(str, result), "defsite": block.pdl__id})]  # type: ignore
#    1571     )
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:1648, in call_python(code, scope)
#    1647 def call_python(code: str, scope: ScopeType) -> PdlLazy[Any]:
# -> 1648     my_namespace = types.SimpleNamespace(PDL_SESSION=__PDL_SESSION, **scope)
#    1649     exec(code, my_namespace.__dict__)  # nosec B102
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_lazy.py:119, in PdlDict.__getitem__(self, key)
#     118 if isinstance(v, PdlLazy):
# --> 119     result = v.result()
#     120 else:
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_lazy.py:167, in PdlApply.result(self)
#     166     return self._data
# --> 167 v = self.x.result()
#     168 self._data = self.f(v)
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_lazy.py:167, in PdlApply.result(self)
#     166     return self._data
# --> 167 v = self.x.result()
#     168 self._data = self.f(v)
#
#     [... skipping similar frames: PdlApply.result at line 167 (1 times)]
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_lazy.py:167, in PdlApply.result(self)
#     166     return self._data
# --> 167 v = self.x.result()
#     168 self._data = self.f(v)
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_lazy.py:38, in PdlConst.result(self)
#      37 while isinstance(self._data, (Future, PdlLazy)):
# ---> 38     self._data = self._data.result()
#      39 return self._data
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/threading.py:359, in Condition.wait(self, timeout)
#     358 if timeout is None:
# --> 359     waiter.acquire()
#     360     gotit = True
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# PDLRuntimeError                           Traceback (most recent call last)
# Cell In[7], line 2
#       1 with RejectionSampling(num_samples=10):
# ----> 2     dist2: Empirical[str] = infer(name_finder)  # type: ignore
#
# File ~/probabilistic/mu-ppl/mu_ppl/inference.py:140, in infer(model, *args, **kwargs)
#     122 def infer(model: Callable[P, T], *args: P.args, **kwargs: P.kwargs) -> Distribution[T]:
#     123     """
#     124     Compute the posterior distribution the possible outputs of a model given its arguments.
#     125
#    (...)
#     138         The posterior distribution
#     139     """
# --> 140     return _HANDLER.infer(model, *args, **kwargs)
#
# File ~/probabilistic/mu-ppl/mu_ppl/inference.py:291, in RejectionSampling.infer(self, model, *args, **kwargs)
#     288         if u <= alpha:
#     289             return value  # accept
# --> 291 samples = [gen() for _ in tqdm(range(self.num_samples))]
#     292 return Empirical(samples)
#
# File ~/probabilistic/mu-ppl/mu_ppl/inference.py:285, in RejectionSampling.infer.<locals>.gen()
#     283 while True:
#     284     self.score = 0  # reset the score
# --> 285     value = model(*args, **kwargs)
#     286     alpha = np.exp(min(0, self.score - self.max_score))
#     287     u = np.random.random()
#
# Cell In[2], line 2, in name_finder()
#       1 def name_finder():
# ----> 2     p = exec_file("name_finder.pdl")
#       3     return p
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl.py:156, in exec_file(prog, config, scope, output)
#     154 if config.get("cwd") is None:
#     155     config["cwd"] = Path(prog).parent
# --> 156 result = exec_program(program, config, scope, loc, output)
#     157 return result
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl.py:74, in exec_program(prog, config, scope, loc, output)
#      72 loc = loc or empty_block_location
#      73 initial_scope = {"pdl_model_default_parameters": get_default_model_parameters()}
# ---> 74 future_result, _, future_scope, trace = process_prog(
#      75     state, scope | initial_scope, prog, loc
#      76 )
#      77 result = future_result.result()
#      78 match output:
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:236, in process_prog(state, scope, prog, loc)
#     221 """Execute a PDL program.
#     222
#     223 Args:
#    (...)
#     233     PDLRuntimeError: If the program raises an error.
#     234 """
#     235 scope = empty_scope | scope
# --> 236 result, document, final_scope, trace = process_block(
#     237     state, scope, block=prog.root, loc=loc
#     238 )
#     239 return result, document, final_scope, trace
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:285, in process_block(state, scope, block, loc)
#     283             yield_result(result.result(), BlockKind.DATA)
#     284     else:
# --> 285         result, background, scope, trace = process_advanced_block_timed(
#     286             state, scope, block, loc
#     287         )
#     288 except EOFError as exc:
#     289     raise PDLRuntimeError(
#     290         "EOF",
#     291         loc=loc,
#     292         trace=ErrorBlock(msg="EOF", pdl__location=loc, program=block),
#     293     ) from exc
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:326, in process_advanced_block_timed(state, scope, block, loc)
#     324 block.pdl__timing = PdlTiming()
#     325 block.pdl__timing.start_nanos = time.time_ns()
# --> 326 result, background, scope, trace = process_advanced_block(state, scope, block, loc)
#     327 block.pdl__timing.end_nanos = time.time_ns()
#     328 match trace:
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:356, in process_advanced_block(state, scope, block, loc)
#     354     state = state.with_role(block.role)
#     355 if len(block.defs) > 0:
# --> 356     scope, defs_trace = process_defs(state, scope, block.defs, loc)
#     357     block = block.model_copy(update={"defs": defs_trace})
#     358 init_state = state
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:920, in process_defs(state, scope, defs, loc)
#     918 state = state.with_yield_result(False)
#     919 state = state.with_yield_background(False)
# --> 920 result, _, _, block_trace = process_block(state, scope, block, newloc)
#     921 scope = scope | PdlDict({x: result})
#     922 defs_trace[x] = block_trace
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:285, in process_block(state, scope, block, loc)
#     283             yield_result(result.result(), BlockKind.DATA)
#     284     else:
# --> 285         result, background, scope, trace = process_advanced_block_timed(
#     286             state, scope, block, loc
#     287         )
#     288 except EOFError as exc:
#     289     raise PDLRuntimeError(
#     290         "EOF",
#     291         loc=loc,
#     292         trace=ErrorBlock(msg="EOF", pdl__location=loc, program=block),
#     293     ) from exc
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:326, in process_advanced_block_timed(state, scope, block, loc)
#     324 block.pdl__timing = PdlTiming()
#     325 block.pdl__timing.start_nanos = time.time_ns()
# --> 326 result, background, scope, trace = process_advanced_block(state, scope, block, loc)
#     327 block.pdl__timing.end_nanos = time.time_ns()
#     328 match trace:
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:356, in process_advanced_block(state, scope, block, loc)
#     354     state = state.with_role(block.role)
#     355 if len(block.defs) > 0:
# --> 356     scope, defs_trace = process_defs(state, scope, block.defs, loc)
#     357     block = block.model_copy(update={"defs": defs_trace})
#     358 init_state = state
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:920, in process_defs(state, scope, defs, loc)
#     918 state = state.with_yield_result(False)
#     919 state = state.with_yield_background(False)
# --> 920 result, _, _, block_trace = process_block(state, scope, block, newloc)
#     921 scope = scope | PdlDict({x: result})
#     922 defs_trace[x] = block_trace
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:295, in process_block(state, scope, block, loc)
#     289     raise PDLRuntimeError(
#     290         "EOF",
#     291         loc=loc,
#     292         trace=ErrorBlock(msg="EOF", pdl__location=loc, program=block),
#     293     ) from exc
#     294 except KeyboardInterrupt as exc:
# --> 295     raise PDLRuntimeError(
#     296         "Keyboard Interrupt",
#     297         loc=loc,
#     298         trace=ErrorBlock(
#     299             msg="Keyboard Interrupt", pdl__location=loc, program=block
#     300         ),
#     301     ) from exc
#     302 scope = scope | {"pdl_context": background}
#     303 return result, background, scope, trace
#
# PDLRuntimeError: Keyboard Interrupt

# %%
viz(dist2)

# %%
with SimpleMetropolis(num_samples=50):
    dist3: Empirical[str] = infer(name_finder)  # type: ignore
# Out:
# 100%|██████████| 50/50 [02:43<00:00,  3.28s/it]

# %%
viz(dist3)

# %%
with MetropolisHastings(num_samples=10):
    dist1: Empirical[str] = infer(name_finder)  # type: ignore
# Out:
# exception calling callback for <Future at 0x127c5abd0 state=finished raised PDLRuntimeError>
# Traceback (most recent call last):
#   File "/Users/lmandel/.pyenv/versions/3.13.0/lib/python3.13/concurrent/futures/_base.py", line 340, in _invoke_callbacks
#     callback(self)
#     ~~~~~~~~^^^^^^
#   File "/Users/lmandel/ml4code/prompt-declaration-language/src/pdl/pdl_llms.py", line 113, in update_end_nanos
#     result = future.result()[1]
#              ~~~~~~~~~~~~~^^
#   File "/Users/lmandel/.pyenv/versions/3.13.0/lib/python3.13/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ~~~~~~~~~~~~~~~~~^^
#   File "/Users/lmandel/.pyenv/versions/3.13.0/lib/python3.13/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/Users/lmandel/ml4code/prompt-declaration-language/src/pdl/pdl_llms.py", line 78, in async_generate_text
#     raise PDLRuntimeError(
#     ...<3 lines>...
#     ) from exc
# pdl.pdl_ast.PDLRuntimeError: Error during 'replicate/ibm-granite/granite-3.2-8b-instruct' model call: litellm.UnprocessableEntityError: ReplicateException - LiteLLM Error - prediction not succeeded - {'id': 'xnr57kr59drm80cnv0vtxmve4c', 'model': 'ibm-granite/granite-3.2-8b-instruct', 'version': 'hidden', 'input': {'prompt': "I am looking for a first name for my future baby. Can you give me one suggestion? I suggest to pick one fro the following list:\n['Gabriel', 'Louis', 'Jules', 'Arthur', 'Noah', 'Adam', 'Isaac', 'Jade', 'Louise', 'Emma', 'Rose', 'Alice', 'Anna', 'Lina', 'Remi', 'Rosa', 'Josephine', 'Odilon', 'Louise', 'Jade', 'Ambre', 'Alba', 'Emma', 'Gabriel', 'Leo', 'Raphael', 'Mael', 'Louis', 'Remi', 'Rosa', 'Josephine', 'Odilon']\n", 'stream': False, 'temperature': 1.5}, 'logs': '', 'output': None, 'data_removed': False, 'error': None, 'status': 'starting', 'created_at': '2025-03-27T15:27:19.371Z', 'urls': {'cancel': 'https://api.replicate.com/v1/predictions/xnr57kr59drm80cnv0vtxmve4c/cancel', 'get': 'https://api.replicate.com/v1/predictions/xnr57kr59drm80cnv0vtxmve4c', 'stream': 'https://stream-b.svc.ric1.c.replicate.net/v1/streams/27gar5cgmnbntzbp4ekux4chdli2oqv64dy7hzfi7zfwv2ahspoq'}}
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm.set_verbose=True'.
# ---------------------------------------------------------------------------
# PDLRuntimeError                           Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[18], line 2
#       1 with MetropolisHastings(num_samples=10):
# ----> 2     dist1: Empirical[str] = infer(name_finder)  # type: ignore
#
# File ~/probabilistic/mu-ppl/mu_ppl/inference.py:140, in infer(model, *args, **kwargs)
#     123 """
#     124 Compute the posterior distribution the possible outputs of a model given its arguments.
#     125
#    (...)
#     138     The posterior distribution
#     139 """
# --> 140 return _HANDLER.infer(model, *args, **kwargs)
#
# File ~/probabilistic/mu-ppl/mu_ppl/inference.py:403, in MetropolisHastings.infer(self, model, *args, **kwargs)
#     402 samples: List[T] = []
# --> 403 new_value = model(*args, **kwargs)  # generate first trace
#     405 for _ in tqdm(range(self.warmups + self.num_samples * self.thinning)):
#
# Cell In[2], line 2, in name_finder()
#       1 def name_finder():
# ----> 2     p = exec_file("name_finder.pdl")
#       3     return p
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl.py:156, in exec_file(prog, config, scope, output)
#     155     config["cwd"] = Path(prog).parent
# --> 156 result = exec_program(program, config, scope, loc, output)
#     157 return result
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl.py:74, in exec_program(prog, config, scope, loc, output)
#      73 initial_scope = {"pdl_model_default_parameters": get_default_model_parameters()}
# ---> 74 future_result, _, future_scope, trace = process_prog(
#      75     state, scope | initial_scope, prog, loc
#      76 )
#      77 result = future_result.result()
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:236, in process_prog(state, scope, prog, loc)
#     235 scope = empty_scope | scope
# --> 236 result, document, final_scope, trace = process_block(
#     237     state, scope, block=prog.root, loc=loc
#     238 )
#     239 return result, document, final_scope, trace
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:285, in process_block(state, scope, block, loc)
#     284     else:
# --> 285         result, background, scope, trace = process_advanced_block_timed(
#     286             state, scope, block, loc
#     287         )
#     288 except EOFError as exc:
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:326, in process_advanced_block_timed(state, scope, block, loc)
#     325 block.pdl__timing.start_nanos = time.time_ns()
# --> 326 result, background, scope, trace = process_advanced_block(state, scope, block, loc)
#     327 block.pdl__timing.end_nanos = time.time_ns()
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:356, in process_advanced_block(state, scope, block, loc)
#     355 if len(block.defs) > 0:
# --> 356     scope, defs_trace = process_defs(state, scope, block.defs, loc)
#     357     block = block.model_copy(update={"defs": defs_trace})
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:920, in process_defs(state, scope, defs, loc)
#     919 state = state.with_yield_background(False)
# --> 920 result, _, _, block_trace = process_block(state, scope, block, newloc)
#     921 scope = scope | PdlDict({x: result})
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:285, in process_block(state, scope, block, loc)
#     284     else:
# --> 285         result, background, scope, trace = process_advanced_block_timed(
#     286             state, scope, block, loc
#     287         )
#     288 except EOFError as exc:
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:326, in process_advanced_block_timed(state, scope, block, loc)
#     325 block.pdl__timing.start_nanos = time.time_ns()
# --> 326 result, background, scope, trace = process_advanced_block(state, scope, block, loc)
#     327 block.pdl__timing.end_nanos = time.time_ns()
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:392, in process_advanced_block(state, scope, block, loc)
#     391 if block.fallback is None:
# --> 392     raise exc from exc
#     393 (
#     394     result,
#     395     background,
#    (...)
#     403     loc=loc,
#     404 )
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:368, in process_advanced_block(state, scope, block, loc)
#     367 try:
# --> 368     result, background, new_scope, trace = process_block_body(
#     369         state, scope, block, loc
#     370     )
#     371     result = lazy_apply(id_with_set_first_use_nanos(block.pdl__timing), result)
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:523, in process_block_body(state, scope, block, loc)
#     522 case LastOfBlock():
# --> 523     result, background, scope, trace = process_blocks_of(
#     524         block,
#     525         "lastOf",
#     526         IterationType.LASTOF,
#     527         state,
#     528         scope,
#     529         loc,
#     530     )
#     531 case ArrayBlock():
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:984, in process_blocks_of(block, field, iteration_type, state, scope, loc, field_alias)
#     983     trace = block.model_copy(update={field: exc.blocks})
# --> 984     raise PDLRuntimeError(
#     985         exc.message,
#     986         loc=exc.loc or loc,
#     987         trace=trace,
#     988     ) from exc
#     989 trace = block.model_copy(update={field: blocks})
#
# PDLRuntimeError: Error during 'replicate/ibm-granite/granite-3.2-8b-instruct' model call: litellm.UnprocessableEntityError: ReplicateException - LiteLLM Error - prediction not succeeded - {'id': 'xnr57kr59drm80cnv0vtxmve4c', 'model': 'ibm-granite/granite-3.2-8b-instruct', 'version': 'hidden', 'input': {'prompt': "I am looking for a first name for my future baby. Can you give me one suggestion? I suggest to pick one fro the following list:\n['Gabriel', 'Louis', 'Jules', 'Arthur', 'Noah', 'Adam', 'Isaac', 'Jade', 'Louise', 'Emma', 'Rose', 'Alice', 'Anna', 'Lina', 'Remi', 'Rosa', 'Josephine', 'Odilon', 'Louise', 'Jade', 'Ambre', 'Alba', 'Emma', 'Gabriel', 'Leo', 'Raphael', 'Mael', 'Louis', 'Remi', 'Rosa', 'Josephine', 'Odilon']\n", 'stream': False, 'temperature': 1.5}, 'logs': '', 'output': None, 'data_removed': False, 'error': None, 'status': 'starting', 'created_at': '2025-03-27T15:27:19.371Z', 'urls': {'cancel': 'https://api.replicate.com/v1/predictions/xnr57kr59drm80cnv0vtxmve4c/cancel', 'get': 'https://api.replicate.com/v1/predictions/xnr57kr59drm80cnv0vtxmve4c', 'stream': 'https://stream-b.svc.ric1.c.replicate.net/v1/streams/27gar5cgmnbntzbp4ekux4chdli2oqv64dy7hzfi7zfwv2ahspoq'}}
#
# The above exception was the direct cause of the following exception:
#
# PDLRuntimeError                           Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[18], line 2
#       1 with MetropolisHastings(num_samples=10):
# ----> 2     dist1: Empirical[str] = infer(name_finder)  # type: ignore
#
# File ~/probabilistic/mu-ppl/mu_ppl/inference.py:140, in infer(model, *args, **kwargs)
#     123 """
#     124 Compute the posterior distribution the possible outputs of a model given its arguments.
#     125
#    (...)
#     138     The posterior distribution
#     139 """
# --> 140 return _HANDLER.infer(model, *args, **kwargs)
#
# File ~/probabilistic/mu-ppl/mu_ppl/inference.py:403, in MetropolisHastings.infer(self, model, *args, **kwargs)
#     402 samples: List[T] = []
# --> 403 new_value = model(*args, **kwargs)  # generate first trace
#     405 for _ in tqdm(range(self.warmups + self.num_samples * self.thinning)):
#
# Cell In[2], line 2, in name_finder()
#       1 def name_finder():
# ----> 2     p = exec_file("name_finder.pdl")
#       3     return p
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl.py:156, in exec_file(prog, config, scope, output)
#     155     config["cwd"] = Path(prog).parent
# --> 156 result = exec_program(program, config, scope, loc, output)
#     157 return result
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl.py:74, in exec_program(prog, config, scope, loc, output)
#      73 initial_scope = {"pdl_model_default_parameters": get_default_model_parameters()}
# ---> 74 future_result, _, future_scope, trace = process_prog(
#      75     state, scope | initial_scope, prog, loc
#      76 )
#      77 result = future_result.result()
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:236, in process_prog(state, scope, prog, loc)
#     235 scope = empty_scope | scope
# --> 236 result, document, final_scope, trace = process_block(
#     237     state, scope, block=prog.root, loc=loc
#     238 )
#     239 return result, document, final_scope, trace
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:285, in process_block(state, scope, block, loc)
#     284     else:
# --> 285         result, background, scope, trace = process_advanced_block_timed(
#     286             state, scope, block, loc
#     287         )
#     288 except EOFError as exc:
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:326, in process_advanced_block_timed(state, scope, block, loc)
#     325 block.pdl__timing.start_nanos = time.time_ns()
# --> 326 result, background, scope, trace = process_advanced_block(state, scope, block, loc)
#     327 block.pdl__timing.end_nanos = time.time_ns()
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:356, in process_advanced_block(state, scope, block, loc)
#     355 if len(block.defs) > 0:
# --> 356     scope, defs_trace = process_defs(state, scope, block.defs, loc)
#     357     block = block.model_copy(update={"defs": defs_trace})
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:920, in process_defs(state, scope, defs, loc)
#     919 state = state.with_yield_background(False)
# --> 920 result, _, _, block_trace = process_block(state, scope, block, newloc)
#     921 scope = scope | PdlDict({x: result})
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:285, in process_block(state, scope, block, loc)
#     284     else:
# --> 285         result, background, scope, trace = process_advanced_block_timed(
#     286             state, scope, block, loc
#     287         )
#     288 except EOFError as exc:
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:326, in process_advanced_block_timed(state, scope, block, loc)
#     325 block.pdl__timing.start_nanos = time.time_ns()
# --> 326 result, background, scope, trace = process_advanced_block(state, scope, block, loc)
#     327 block.pdl__timing.end_nanos = time.time_ns()
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:392, in process_advanced_block(state, scope, block, loc)
#     391 if block.fallback is None:
# --> 392     raise exc from exc
#     393 (
#     394     result,
#     395     background,
#    (...)
#     403     loc=loc,
#     404 )
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:368, in process_advanced_block(state, scope, block, loc)
#     367 try:
# --> 368     result, background, new_scope, trace = process_block_body(
#     369         state, scope, block, loc
#     370     )
#     371     result = lazy_apply(id_with_set_first_use_nanos(block.pdl__timing), result)
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:523, in process_block_body(state, scope, block, loc)
#     522 case LastOfBlock():
# --> 523     result, background, scope, trace = process_blocks_of(
#     524         block,
#     525         "lastOf",
#     526         IterationType.LASTOF,
#     527         state,
#     528         scope,
#     529         loc,
#     530     )
#     531 case ArrayBlock():
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:984, in process_blocks_of(block, field, iteration_type, state, scope, loc, field_alias)
#     983     trace = block.model_copy(update={field: exc.blocks})
# --> 984     raise PDLRuntimeError(
#     985         exc.message,
#     986         loc=exc.loc or loc,
#     987         trace=trace,
#     988     ) from exc
#     989 trace = block.model_copy(update={field: blocks})
#
# PDLRuntimeError: Error during 'replicate/ibm-granite/granite-3.2-8b-instruct' model call: litellm.UnprocessableEntityError: ReplicateException - LiteLLM Error - prediction not succeeded - {'id': 'xnr57kr59drm80cnv0vtxmve4c', 'model': 'ibm-granite/granite-3.2-8b-instruct', 'version': 'hidden', 'input': {'prompt': "I am looking for a first name for my future baby. Can you give me one suggestion? I suggest to pick one fro the following list:\n['Gabriel', 'Louis', 'Jules', 'Arthur', 'Noah', 'Adam', 'Isaac', 'Jade', 'Louise', 'Emma', 'Rose', 'Alice', 'Anna', 'Lina', 'Remi', 'Rosa', 'Josephine', 'Odilon', 'Louise', 'Jade', 'Ambre', 'Alba', 'Emma', 'Gabriel', 'Leo', 'Raphael', 'Mael', 'Louis', 'Remi', 'Rosa', 'Josephine', 'Odilon']\n", 'stream': False, 'temperature': 1.5}, 'logs': '', 'output': None, 'data_removed': False, 'error': None, 'status': 'starting', 'created_at': '2025-03-27T15:27:19.371Z', 'urls': {'cancel': 'https://api.replicate.com/v1/predictions/xnr57kr59drm80cnv0vtxmve4c/cancel', 'get': 'https://api.replicate.com/v1/predictions/xnr57kr59drm80cnv0vtxmve4c', 'stream': 'https://stream-b.svc.ric1.c.replicate.net/v1/streams/27gar5cgmnbntzbp4ekux4chdli2oqv64dy7hzfi7zfwv2ahspoq'}}
#
# The above exception was the direct cause of the following exception:
#
# PDLRuntimeError                           Traceback (most recent call last)
# Cell In[18], line 2
#       1 with MetropolisHastings(num_samples=10):
# ----> 2     dist1: Empirical[str] = infer(name_finder)  # type: ignore
#
# File ~/probabilistic/mu-ppl/mu_ppl/inference.py:140, in infer(model, *args, **kwargs)
#     122 def infer(model: Callable[P, T], *args: P.args, **kwargs: P.kwargs) -> Distribution[T]:
#     123     """
#     124     Compute the posterior distribution the possible outputs of a model given its arguments.
#     125
#    (...)
#     138         The posterior distribution
#     139     """
# --> 140     return _HANDLER.infer(model, *args, **kwargs)
#
# File ~/probabilistic/mu-ppl/mu_ppl/inference.py:403, in MetropolisHastings.infer(self, model, *args, **kwargs)
#     399 def infer(
#     400     self, model: Callable[P, T], *args: P.args, **kwargs: P.kwargs
#     401 ) -> Empirical[T]:
#     402     samples: List[T] = []
# --> 403     new_value = model(*args, **kwargs)  # generate first trace
#     405     for _ in tqdm(range(self.warmups + self.num_samples * self.thinning)):
#     406         p_state = self.score, self.x_samples, self.x_scores  # store state
#
# Cell In[2], line 2, in name_finder()
#       1 def name_finder():
# ----> 2     p = exec_file("name_finder.pdl")
#       3     return p
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl.py:156, in exec_file(prog, config, scope, output)
#     154 if config.get("cwd") is None:
#     155     config["cwd"] = Path(prog).parent
# --> 156 result = exec_program(program, config, scope, loc, output)
#     157 return result
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl.py:74, in exec_program(prog, config, scope, loc, output)
#      72 loc = loc or empty_block_location
#      73 initial_scope = {"pdl_model_default_parameters": get_default_model_parameters()}
# ---> 74 future_result, _, future_scope, trace = process_prog(
#      75     state, scope | initial_scope, prog, loc
#      76 )
#      77 result = future_result.result()
#      78 match output:
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:236, in process_prog(state, scope, prog, loc)
#     221 """Execute a PDL program.
#     222
#     223 Args:
#    (...)
#     233     PDLRuntimeError: If the program raises an error.
#     234 """
#     235 scope = empty_scope | scope
# --> 236 result, document, final_scope, trace = process_block(
#     237     state, scope, block=prog.root, loc=loc
#     238 )
#     239 return result, document, final_scope, trace
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:285, in process_block(state, scope, block, loc)
#     283             yield_result(result.result(), BlockKind.DATA)
#     284     else:
# --> 285         result, background, scope, trace = process_advanced_block_timed(
#     286             state, scope, block, loc
#     287         )
#     288 except EOFError as exc:
#     289     raise PDLRuntimeError(
#     290         "EOF",
#     291         loc=loc,
#     292         trace=ErrorBlock(msg="EOF", pdl__location=loc, program=block),
#     293     ) from exc
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:326, in process_advanced_block_timed(state, scope, block, loc)
#     324 block.pdl__timing = PdlTiming()
#     325 block.pdl__timing.start_nanos = time.time_ns()
# --> 326 result, background, scope, trace = process_advanced_block(state, scope, block, loc)
#     327 block.pdl__timing.end_nanos = time.time_ns()
#     328 match trace:
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:356, in process_advanced_block(state, scope, block, loc)
#     354     state = state.with_role(block.role)
#     355 if len(block.defs) > 0:
# --> 356     scope, defs_trace = process_defs(state, scope, block.defs, loc)
#     357     block = block.model_copy(update={"defs": defs_trace})
#     358 init_state = state
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:920, in process_defs(state, scope, defs, loc)
#     918 state = state.with_yield_result(False)
#     919 state = state.with_yield_background(False)
# --> 920 result, _, _, block_trace = process_block(state, scope, block, newloc)
#     921 scope = scope | PdlDict({x: result})
#     922 defs_trace[x] = block_trace
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:285, in process_block(state, scope, block, loc)
#     283             yield_result(result.result(), BlockKind.DATA)
#     284     else:
# --> 285         result, background, scope, trace = process_advanced_block_timed(
#     286             state, scope, block, loc
#     287         )
#     288 except EOFError as exc:
#     289     raise PDLRuntimeError(
#     290         "EOF",
#     291         loc=loc,
#     292         trace=ErrorBlock(msg="EOF", pdl__location=loc, program=block),
#     293     ) from exc
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:326, in process_advanced_block_timed(state, scope, block, loc)
#     324 block.pdl__timing = PdlTiming()
#     325 block.pdl__timing.start_nanos = time.time_ns()
# --> 326 result, background, scope, trace = process_advanced_block(state, scope, block, loc)
#     327 block.pdl__timing.end_nanos = time.time_ns()
#     328 match trace:
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:392, in process_advanced_block(state, scope, block, loc)
#     390 except Exception as exc:
#     391     if block.fallback is None:
# --> 392         raise exc from exc
#     393     (
#     394         result,
#     395         background,
#    (...)
#     403         loc=loc,
#     404     )
#     405     if block.spec is not None and not isinstance(block, FunctionBlock):
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:368, in process_advanced_block(state, scope, block, loc)
#     364 state = state.with_yield_background(
#     365     state.yield_background and context_in_contribute(block)
#     366 )
#     367 try:
# --> 368     result, background, new_scope, trace = process_block_body(
#     369         state, scope, block, loc
#     370     )
#     371     result = lazy_apply(id_with_set_first_use_nanos(block.pdl__timing), result)
#     372     background = lazy_apply(
#     373         id_with_set_first_use_nanos(block.pdl__timing), background
#     374     )
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:523, in process_block_body(state, scope, block, loc)
#     514     result, background, scope, trace = process_blocks_of(
#     515         block,
#     516         "text",
#    (...)
#     520         loc,
#     521     )
#     522 case LastOfBlock():
# --> 523     result, background, scope, trace = process_blocks_of(
#     524         block,
#     525         "lastOf",
#     526         IterationType.LASTOF,
#     527         state,
#     528         scope,
#     529         loc,
#     530     )
#     531 case ArrayBlock():
#     532     result, background, scope, trace = process_blocks_of(
#     533         block,
#     534         "array",
#    (...)
#     538         loc,
#     539     )
#
# File ~/ml4code/prompt-declaration-language/src/pdl/pdl_interpreter.py:984, in process_blocks_of(block, field, iteration_type, state, scope, loc, field_alias)
#     982 except PDLRuntimeProcessBlocksError as exc:
#     983     trace = block.model_copy(update={field: exc.blocks})
# --> 984     raise PDLRuntimeError(
#     985         exc.message,
#     986         loc=exc.loc or loc,
#     987         trace=trace,
#     988     ) from exc
#     989 trace = block.model_copy(update={field: blocks})
#     990 return result, background, scope, trace
#
# PDLRuntimeError: Error during 'replicate/ibm-granite/granite-3.2-8b-instruct' model call: litellm.UnprocessableEntityError: ReplicateException - LiteLLM Error - prediction not succeeded - {'id': 'xnr57kr59drm80cnv0vtxmve4c', 'model': 'ibm-granite/granite-3.2-8b-instruct', 'version': 'hidden', 'input': {'prompt': "I am looking for a first name for my future baby. Can you give me one suggestion? I suggest to pick one fro the following list:\n['Gabriel', 'Louis', 'Jules', 'Arthur', 'Noah', 'Adam', 'Isaac', 'Jade', 'Louise', 'Emma', 'Rose', 'Alice', 'Anna', 'Lina', 'Remi', 'Rosa', 'Josephine', 'Odilon', 'Louise', 'Jade', 'Ambre', 'Alba', 'Emma', 'Gabriel', 'Leo', 'Raphael', 'Mael', 'Louis', 'Remi', 'Rosa', 'Josephine', 'Odilon']\n", 'stream': False, 'temperature': 1.5}, 'logs': '', 'output': None, 'data_removed': False, 'error': None, 'status': 'starting', 'created_at': '2025-03-27T15:27:19.371Z', 'urls': {'cancel': 'https://api.replicate.com/v1/predictions/xnr57kr59drm80cnv0vtxmve4c/cancel', 'get': 'https://api.replicate.com/v1/predictions/xnr57kr59drm80cnv0vtxmve4c', 'stream': 'https://stream-b.svc.ric1.c.replicate.net/v1/streams/27gar5cgmnbntzbp4ekux4chdli2oqv64dy7hzfi7zfwv2ahspoq'}}

# %%
viz(dist1)
